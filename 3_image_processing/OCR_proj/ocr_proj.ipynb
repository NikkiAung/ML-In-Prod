# %%
import os
import cv2
import matplotlib.pyplot as plt

root_path = os.getcwd()
cv_img_path = root_path+r"/config/image.png"
input_img =  cv2.imread(cv_img_path)
plt.imshow(input_img)

# %%
copy_img = input_img.copy()

# Convert to Gray
img_gray = cv2.cvtColor(copy_img, cv2.COLOR_BGR2GRAY)

# Make GaussianBlur (Normalized the colors)
blurred = cv2.GaussianBlur(img_gray,(5,5),0)

# Perform Thresholding (Weak lines are disappeared)
thresh = cv2.threshold(blurred, 200, 255, cv2.THRESH_BINARY)[1]

# Perform Bilateral Filter
gray = cv2.bilateralFilter(thresh, 1, 100, 150)

# Perform Canny Edges Detections (Clear lines are become more clear)
canny_img = cv2.Canny(gray, 20, 250)
plt.imshow(canny_img)

# %%
contours, hierarchy = cv2.findContours(canny_img, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
rect_list = []
for i in contours:
    i_area = cv2.contourArea(i)
    if i_area > 4600:
        print(i_area)
        peri = cv2.arcLength(i,True)
        
        approx = cv2.approxPolyDP(i,0.02 * peri, True)
        print(approx)
        rect_list.append(approx)
        cv2.drawContours(copy_img, [approx], -1, (0, 255, 0), 3)
# Out:
# 158093.5
# [[[ 14 299]]
#
#  [[ 18 532]]
#
#  [[673 529]]
#
#  [[668 295]]]
# 158090.5
# [[[ 14 299]]
#
#  [[668 295]]
#
#  [[673 529]]
#
#  [[ 18 532]]]
# 101922.5
# [[[ 16 124]]
#
#  [[ 20 273]]
#
#  [[671 271]]
#
#  [[666 117]]]
# 101862.0
# [[[ 16 124]]
#
#  [[666 117]]
#
#  [[671 270]]
#
#  [[ 20 273]]]

# %%
rect_list
# Out:
# [array([[[ 14, 299]],
#
#         [[ 18, 532]],
#
#         [[673, 529]],
#
#         [[668, 295]]], dtype=int32),
#  array([[[ 14, 299]],
#
#         [[668, 295]],
#
#         [[673, 529]],
#
#         [[ 18, 532]]], dtype=int32),
#  array([[[ 16, 124]],
#
#         [[ 20, 273]],
#
#         [[671, 271]],
#
#         [[666, 117]]], dtype=int32),
#  array([[[ 16, 124]],
#
#         [[666, 117]],
#
#         [[671, 270]],
#
#         [[ 20, 273]]], dtype=int32)]

# %%
plt.imshow(copy_img)

# %%
import numpy as np
i = 2
x_indexes = [rect_list[i][0][0][0], rect_list[i][1][0][0], rect_list[i][2][0][0], rect_list[i][3][0][0]]
y_indexes = [rect_list[i][0][0][1], rect_list[i][1][0][1], rect_list[i][2][0][1], rect_list[i][3][0][1]]
print(x_indexes)
print(y_indexes)

x1 = np.min(x_indexes) #16 
x2 = np.max(x_indexes) #671

y1 = np.min(y_indexes) #117
y2 = np.max(y_indexes) #273

tocropped_img = input_img.copy()
cropped_img = tocropped_img[y1:y2, x1:x2, :]

cv2.imwrite('result_img.png',cropped_img)

plt.imshow(cropped_img)
# Out:
# [np.int32(16), np.int32(20), np.int32(671), np.int32(666)]
# [np.int32(124), np.int32(273), np.int32(271), np.int32(117)]

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /opt/anaconda3/envs/dev_env/lib/python3.10/site-packages (1.0.1)

# %%
# !pip install google-cloud-vision
# Out:
# Collecting google-cloud-vision
#   Downloading google_cloud_vision-3.9.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision)
#   Using cached google_api_core-2.24.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 (from google-cloud-vision)
#   Downloading google_auth-2.37.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-cloud-vision)
#   Downloading proto_plus-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /opt/anaconda3/envs/dev_env/lib/python3.10/site-packages (from google-cloud-vision) (5.29.3)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision)
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/anaconda3/envs/dev_env/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.32.3)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision)
#   Downloading grpcio-1.69.0-cp310-cp310-macosx_12_0_universal2.whl.metadata (3.9 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision)
#   Downloading grpcio_status-1.69.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision)
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/dev_env/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/dev_env/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/dev_env/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/dev_env/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2024.12.14)
# Downloading google_cloud_vision-3.9.0-py2.py3-none-any.whl (514 kB)
# Downloading google_api_core-2.24.0-py3-none-any.whl (158 kB)
# Downloading google_auth-2.37.0-py2.py3-none-any.whl (209 kB)
# Downloading proto_plus-1.25.0-py3-none-any.whl (50 kB)
# Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
# Downloading grpcio-1.69.0-cp310-cp310-macosx_12_0_universal2.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 20.3 MB/s eta 0:00:00 0:00:01
# Downloading grpcio_status-1.69.0-py3-none-any.whl (14 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: pyasn1, proto-plus, grpcio, googleapis-common-protos, cachetools, rsa, pyasn1-modules, grpcio-status, google-auth, google-api-core, google-cloud-vision
# Successfully installed cachetools-5.5.0 google-api-core-2.24.0 google-auth-2.37.0 google-cloud-vision-3.9.0 googleapis-common-protos-1.66.0 grpcio-1.69.0 grpcio-status-1.69.0 proto-plus-1.25.0 pyasn1-0.6.1 pyasn1-modules-0.4.1 rsa-4.9

# %%
from dotenv import load_dotenv
import os
load_dotenv()
print(os.getenv('GOOGLE_APPLICATION_CREDENTIALS'))
# Out:
# /Users/aungnandaoo/Desktop/ML-in-Prod/3_image_processing/OCR_proj/credentials/service_acc.json

# %%
from google.cloud import vision
import io

img_file = io.open("result_img.png",'rb')
content = img_file.read()

client = vision.ImageAnnotatorClient()
image = vision.Image(content=content)

# %%
response = client.text_detection(image)

response
# Out:
# text_annotations {
#   locale: "ja"
#   description: "カブシキガイシャ ソウケン\n株式会社 惣建\n所\n名\n所\n〒573-1106\n大阪府枚方市町楠葉1丁目17-10-203\n在\n地\n京阪 樟葉駅 から 徒歩1分\n代表者名 代表取締役\n法人番号\n4120001219359\n東野想平\nホームページ\n企業全体\n就菜場所\n2人\n2人\n(うち女性)\n人\n(うちパート)\n0人\n設\n立平成31年\n資本金\n従業員数 事内容 会社の特長\n日本のインフラ設備を手掛ける大手ゼネコンから仕事を頂き、 オフ\nィスから図面の作図や数量計算などを行い、 現場を支援する業務を\n内行っております。 施工管理としての現場の仕事を行っています。\n会社を設立して浅いですが、 業績も右肩上がりをキープしておりま\nす。人数が少ないからこそ自分の意見が言いやすい環境です。 一緒\nに会社を作っていけるのが特徴です。"
#   bounding_poly {
#     vertices {
#       x: 4
#     }
#     vertices {
#       x: 651
#     }
#     vertices {
#       x: 651
#       y: 152
#     }
#     vertices {
#       x: 4
#       y: 152
#     }
#   }
# }
# text_annotations {
#   description: "カブシキガイシャ"
#   bounding_poly {
#     vertices {
#       x: 28
#       y: 3
#     }
#     vertices {
#       x: 78
#       y: 3
#     }
#     vertices {
#       x: 78
#       y: 10
#     }
#     vertices {
#       x: 28
#       y: 10
#     }
#   }
# }
# text_annotations {
#   description: "ソウケン"
#   bounding_poly {
#     vertices {
#       x: 84
#       y: 3
#     }
#     vertices {
#       x: 111
#       y: 3
#     }
#     vertices {
#       x: 111
#       y: 9
#     }
#     vertices {
#       x: 84
#       y: 9
#     }
#   }
# }
# text_annotations {
#   description: "株式会社"
#   bounding_poly {
#     vertices {
#       x: 28
#       y: 22
#     }
#     vertices {
#       x: 64
#       y: 22
#     }
#     vertices {
#       x: 64
#       y: 31
#     }
#     vertices {
#       x: 28
#       y: 31
#     }
#   }
# }
# text_annotations {
#   description: "惣建"
#   bounding_poly {
#     vertices {
#       x: 74
#       y: 22
#     }
#     vertices {
#       x: 93
#       y: 22
#     }
#     vertices {
#       x: 93
#       y: 31
#     }
#     vertices {
#       x: 74
#       y: 31
#     }
#   }
# }
# text_annotations {
#   description: "所"
#   bounding_poly {
#     vertices {
#       x: 4
#       y: 28
#     }
#     vertices {
#       x: 14
#       y: 28
#     }
#     vertices {
#       x: 14
#       y: 36
#     }
#     vertices {
#       x: 4
#       y: 36
#     }
#   }
# }
# text_annotations {
#   description: "名"
#   bounding_poly {
#     vertices {
#       x: 4
#       y: 39
#     }
#     vertices {
#       x: 12
#       y: 39
#     }
#     vertices {
#       x: 12
#       y: 47
#     }
#     vertices {
#       x: 4
#       y: 47
#     }
#   }
# }
# text_annotations {
#   description: "所"
#   bounding_poly {
#     vertices {
#       x: 4
#       y: 59
#     }
#     vertices {
#       x: 13
#       y: 59
#     }
#     vertices {
#       x: 13
#       y: 67
#     }
#     vertices {
#       x: 4
#       y: 67
#     }
#   }
# }
# text_annotations {
#   description: "〒573-1106"
#   bounding_poly {
#     vertices {
#       x: 28
#       y: 63
#     }
#     vertices {
#       x: 75
#       y: 62
#     }
#     vertices {
#       x: 75
#       y: 71
#     }
#     vertices {
#       x: 28
#       y: 72
#     }
#   }
# }
# text_annotations {
#   description: "大阪"
#   bounding_poly {
#     vertices {
#       x: 27
#       y: 73
#     }
#     vertices {
#       x: 45
#       y: 73
#     }
#     vertices {
#       x: 45
#       y: 82
#     }
#     vertices {
#       x: 27
#       y: 82
#     }
#   }
# }
# text_annotations {
#   description: "府"
#   bounding_poly {
#     vertices {
#       x: 46
#       y: 73
#     }
#     vertices {
#       x: 56
#       y: 73
#     }
#     vertices {
#       x: 56
#       y: 82
#     }
#     vertices {
#       x: 46
#       y: 82
#     }
#   }
# }
# text_annotations {
#   description: "枚方"
#   bounding_poly {
#     vertices {
#       x: 55
#       y: 73
#     }
#     vertices {
#       x: 73
#       y: 73
#     }
#     vertices {
#       x: 73
#       y: 82
#     }
#     vertices {
#       x: 55
#       y: 82
#     }
#   }
# }
# text_annotations {
#   description: "市"
#   bounding_poly {
#     vertices {
#       x: 75
#       y: 73
#     }
#     vertices {
#       x: 83
#       y: 73
#     }
#     vertices {
#       x: 83
#       y: 82
#     }
#     vertices {
#       x: 75
#       y: 82
#     }
#   }
# }
# text_annotations {
#   description: "町楠葉"
#   bounding_poly {
#     vertices {
#       x: 83
#       y: 73
#     }
#     vertices {
#       x: 110
#       y: 73
#     }
#     vertices {
#       x: 110
#       y: 82
#     }
#     vertices {
#       x: 83
#       y: 82
#     }
#   }
# }
# text_annotations {
#   description: "1"
#   bounding_poly {
#     vertices {
#       x: 115
#       y: 73
#     }
#     vertices {
#       x: 117
#       y: 73
#     }
#     vertices {
#       x: 117
#       y: 82
#     }
#     vertices {
#       x: 115
#       y: 82
#     }
#   }
# }
# text_annotations {
#   description: "丁目"
#   bounding_poly {
#     vertices {
#       x: 121
#       y: 73
#     }
#     vertices {
#       x: 139
#       y: 73
#     }
#     vertices {
#       x: 139
#       y: 82
#     }
#     vertices {
#       x: 121
#       y: 82
#     }
#   }
# }
# text_annotations {
#   description: "17-10-203"
#   bounding_poly {
#     vertices {
#       x: 143
#       y: 73
#     }
#     vertices {
#       x: 222
#       y: 73
#     }
#     vertices {
#       x: 222
#       y: 82
#     }
#     vertices {
#       x: 143
#       y: 82
#     }
#   }
# }
# text_annotations {
#   description: "在"
#   bounding_poly {
#     vertices {
#       x: 4
#       y: 82
#     }
#     vertices {
#       x: 13
#       y: 82
#     }
#     vertices {
#       x: 13
#       y: 89
#     }
#     vertices {
#       x: 4
#       y: 89
#     }
#   }
# }
# text_annotations {
#   description: "地"
#   bounding_poly {
#     vertices {
#       x: 5
#       y: 106
#     }
#     vertices {
#       x: 13
#       y: 106
#     }
#     vertices {
#       x: 13
#       y: 113
#     }
#     vertices {
#       x: 5
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "京阪"
#   bounding_poly {
#     vertices {
#       x: 28
#       y: 101
#     }
#     vertices {
#       x: 45
#       y: 101
#     }
#     vertices {
#       x: 45
#       y: 110
#     }
#     vertices {
#       x: 28
#       y: 110
#     }
#   }
# }
# text_annotations {
#   description: "樟葉"
#   bounding_poly {
#     vertices {
#       x: 55
#       y: 101
#     }
#     vertices {
#       x: 72
#       y: 101
#     }
#     vertices {
#       x: 72
#       y: 110
#     }
#     vertices {
#       x: 55
#       y: 110
#     }
#   }
# }
# text_annotations {
#   description: "駅"
#   bounding_poly {
#     vertices {
#       x: 75
#       y: 101
#     }
#     vertices {
#       x: 83
#       y: 101
#     }
#     vertices {
#       x: 83
#       y: 110
#     }
#     vertices {
#       x: 75
#       y: 110
#     }
#   }
# }
# text_annotations {
#   description: "から"
#   bounding_poly {
#     vertices {
#       x: 94
#       y: 101
#     }
#     vertices {
#       x: 110
#       y: 101
#     }
#     vertices {
#       x: 110
#       y: 110
#     }
#     vertices {
#       x: 94
#       y: 110
#     }
#   }
# }
# text_annotations {
#   description: "徒歩"
#   bounding_poly {
#     vertices {
#       x: 121
#       y: 101
#     }
#     vertices {
#       x: 139
#       y: 101
#     }
#     vertices {
#       x: 139
#       y: 110
#     }
#     vertices {
#       x: 121
#       y: 110
#     }
#   }
# }
# text_annotations {
#   description: "1"
#   bounding_poly {
#     vertices {
#       x: 141
#       y: 101
#     }
#     vertices {
#       x: 143
#       y: 101
#     }
#     vertices {
#       x: 143
#       y: 110
#     }
#     vertices {
#       x: 141
#       y: 110
#     }
#   }
# }
# text_annotations {
#   description: "分"
#   bounding_poly {
#     vertices {
#       x: 145
#       y: 101
#     }
#     vertices {
#       x: 154
#       y: 101
#     }
#     vertices {
#       x: 154
#       y: 110
#     }
#     vertices {
#       x: 145
#       y: 110
#     }
#   }
# }
# text_annotations {
#   description: "代表"
#   bounding_poly {
#     vertices {
#       x: 6
#       y: 127
#     }
#     vertices {
#       x: 24
#       y: 127
#     }
#     vertices {
#       x: 24
#       y: 135
#     }
#     vertices {
#       x: 6
#       y: 135
#     }
#   }
# }
# text_annotations {
#   description: "者"
#   bounding_poly {
#     vertices {
#       x: 26
#       y: 127
#     }
#     vertices {
#       x: 35
#       y: 127
#     }
#     vertices {
#       x: 35
#       y: 135
#     }
#     vertices {
#       x: 26
#       y: 135
#     }
#   }
# }
# text_annotations {
#   description: "名"
#   bounding_poly {
#     vertices {
#       x: 37
#       y: 127
#     }
#     vertices {
#       x: 45
#       y: 127
#     }
#     vertices {
#       x: 45
#       y: 135
#     }
#     vertices {
#       x: 37
#       y: 135
#     }
#   }
# }
# text_annotations {
#   description: "代表"
#   bounding_poly {
#     vertices {
#       x: 59
#       y: 127
#     }
#     vertices {
#       x: 75
#       y: 127
#     }
#     vertices {
#       x: 75
#       y: 134
#     }
#     vertices {
#       x: 59
#       y: 134
#     }
#   }
# }
# text_annotations {
#   description: "取締"
#   bounding_poly {
#     vertices {
#       x: 75
#       y: 127
#     }
#     vertices {
#       x: 91
#       y: 127
#     }
#     vertices {
#       x: 91
#       y: 134
#     }
#     vertices {
#       x: 75
#       y: 134
#     }
#   }
# }
# text_annotations {
#   description: "役"
#   bounding_poly {
#     vertices {
#       x: 91
#       y: 127
#     }
#     vertices {
#       x: 100
#       y: 127
#     }
#     vertices {
#       x: 100
#       y: 134
#     }
#     vertices {
#       x: 91
#       y: 134
#     }
#   }
# }
# text_annotations {
#   description: "法人"
#   bounding_poly {
#     vertices {
#       x: 6
#       y: 145
#     }
#     vertices {
#       x: 25
#       y: 145
#     }
#     vertices {
#       x: 25
#       y: 152
#     }
#     vertices {
#       x: 6
#       y: 152
#     }
#   }
# }
# text_annotations {
#   description: "番号"
#   bounding_poly {
#     vertices {
#       x: 28
#       y: 145
#     }
#     vertices {
#       x: 46
#       y: 145
#     }
#     vertices {
#       x: 46
#       y: 152
#     }
#     vertices {
#       x: 28
#       y: 152
#     }
#   }
# }
# text_annotations {
#   description: "4120001219359"
#   bounding_poly {
#     vertices {
#       x: 58
#       y: 145
#     }
#     vertices {
#       x: 112
#       y: 145
#     }
#     vertices {
#       x: 112
#       y: 152
#     }
#     vertices {
#       x: 58
#       y: 152
#     }
#   }
# }
# text_annotations {
#   description: "東"
#   bounding_poly {
#     vertices {
#       x: 206
#       y: 127
#     }
#     vertices {
#       x: 214
#       y: 127
#     }
#     vertices {
#       x: 214
#       y: 135
#     }
#     vertices {
#       x: 206
#       y: 135
#     }
#   }
# }
# text_annotations {
#   description: "野"
#   bounding_poly {
#     vertices {
#       x: 215
#       y: 127
#     }
#     vertices {
#       x: 223
#       y: 127
#     }
#     vertices {
#       x: 223
#       y: 135
#     }
#     vertices {
#       x: 215
#       y: 135
#     }
#   }
# }
# text_annotations {
#   description: "想"
#   bounding_poly {
#     vertices {
#       x: 231
#       y: 127
#     }
#     vertices {
#       x: 239
#       y: 127
#     }
#     vertices {
#       x: 239
#       y: 135
#     }
#     vertices {
#       x: 231
#       y: 135
#     }
#   }
# }
# text_annotations {
#   description: "平"
#   bounding_poly {
#     vertices {
#       x: 239
#       y: 127
#     }
#     vertices {
#       x: 247
#       y: 127
#     }
#     vertices {
#       x: 247
#       y: 135
#     }
#     vertices {
#       x: 239
#       y: 135
#     }
#   }
# }
# text_annotations {
#   description: "ホームページ"
#   bounding_poly {
#     vertices {
#       x: 145
#       y: 145
#     }
#     vertices {
#       x: 196
#       y: 145
#     }
#     vertices {
#       x: 196
#       y: 151
#     }
#     vertices {
#       x: 145
#       y: 151
#     }
#   }
# }
# text_annotations {
#   description: "企業"
#   bounding_poly {
#     vertices {
#       x: 410
#       y: 1
#     }
#     vertices {
#       x: 427
#       y: 1
#     }
#     vertices {
#       x: 427
#       y: 10
#     }
#     vertices {
#       x: 410
#       y: 10
#     }
#   }
# }
# text_annotations {
#   description: "全体"
#   bounding_poly {
#     vertices {
#       x: 429
#       y: 1
#     }
#     vertices {
#       x: 447
#       y: 1
#     }
#     vertices {
#       x: 447
#       y: 9
#     }
#     vertices {
#       x: 429
#       y: 9
#     }
#   }
# }
# text_annotations {
#   description: "就"
#   bounding_poly {
#     vertices {
#       x: 475
#       y: 2
#     }
#     vertices {
#       x: 484
#       y: 2
#     }
#     vertices {
#       x: 484
#       y: 10
#     }
#     vertices {
#       x: 475
#       y: 10
#     }
#   }
# }
# text_annotations {
#   description: "菜"
#   bounding_poly {
#     vertices {
#       x: 485
#       y: 2
#     }
#     vertices {
#       x: 494
#       y: 2
#     }
#     vertices {
#       x: 494
#       y: 10
#     }
#     vertices {
#       x: 485
#       y: 10
#     }
#   }
# }
# text_annotations {
#   description: "場所"
#   bounding_poly {
#     vertices {
#       x: 494
#       y: 2
#     }
#     vertices {
#       x: 513
#       y: 2
#     }
#     vertices {
#       x: 513
#       y: 10
#     }
#     vertices {
#       x: 494
#       y: 10
#     }
#   }
# }
# text_annotations {
#   description: "2"
#   bounding_poly {
#     vertices {
#       x: 434
#       y: 21
#     }
#     vertices {
#       x: 438
#       y: 21
#     }
#     vertices {
#       x: 438
#       y: 27
#     }
#     vertices {
#       x: 434
#       y: 27
#     }
#   }
# }
# text_annotations {
#   description: "人"
#   bounding_poly {
#     vertices {
#       x: 439
#       y: 21
#     }
#     vertices {
#       x: 448
#       y: 21
#     }
#     vertices {
#       x: 448
#       y: 27
#     }
#     vertices {
#       x: 439
#       y: 27
#     }
#   }
# }
# text_annotations {
#   description: "2"
#   bounding_poly {
#     vertices {
#       x: 499
#       y: 21
#     }
#     vertices {
#       x: 503
#       y: 21
#     }
#     vertices {
#       x: 503
#       y: 27
#     }
#     vertices {
#       x: 499
#       y: 27
#     }
#   }
# }
# text_annotations {
#   description: "人"
#   bounding_poly {
#     vertices {
#       x: 504
#       y: 21
#     }
#     vertices {
#       x: 512
#       y: 21
#     }
#     vertices {
#       x: 512
#       y: 27
#     }
#     vertices {
#       x: 504
#       y: 27
#     }
#   }
# }
# text_annotations {
#   description: "("
#   bounding_poly {
#     vertices {
#       x: 539
#       y: 2
#     }
#     vertices {
#       x: 543
#       y: 2
#     }
#     vertices {
#       x: 543
#       y: 10
#     }
#     vertices {
#       x: 539
#       y: 10
#     }
#   }
# }
# text_annotations {
#   description: "うち"
#   bounding_poly {
#     vertices {
#       x: 544
#       y: 2
#     }
#     vertices {
#       x: 557
#       y: 2
#     }
#     vertices {
#       x: 557
#       y: 10
#     }
#     vertices {
#       x: 544
#       y: 10
#     }
#   }
# }
# text_annotations {
#   description: "女性"
#   bounding_poly {
#     vertices {
#       x: 559
#       y: 2
#     }
#     vertices {
#       x: 576
#       y: 2
#     }
#     vertices {
#       x: 576
#       y: 10
#     }
#     vertices {
#       x: 559
#       y: 10
#     }
#   }
# }
# text_annotations {
#   description: ")"
#   bounding_poly {
#     vertices {
#       x: 575
#       y: 2
#     }
#     vertices {
#       x: 578
#       y: 2
#     }
#     vertices {
#       x: 578
#       y: 10
#     }
#     vertices {
#       x: 575
#       y: 10
#     }
#   }
# }
# text_annotations {
#   description: "人"
#   bounding_poly {
#     vertices {
#       x: 568
#       y: 20
#     }
#     vertices {
#       x: 577
#       y: 20
#     }
#     vertices {
#       x: 577
#       y: 27
#     }
#     vertices {
#       x: 568
#       y: 27
#     }
#   }
# }
# text_annotations {
#   description: "("
#   bounding_poly {
#     vertices {
#       x: 605
#       y: 2
#     }
#     vertices {
#       x: 609
#       y: 2
#     }
#     vertices {
#       x: 609
#       y: 10
#     }
#     vertices {
#       x: 605
#       y: 10
#     }
#   }
# }
# text_annotations {
#   description: "うち"
#   bounding_poly {
#     vertices {
#       x: 607
#       y: 1
#     }
#     vertices {
#       x: 620
#       y: 1
#     }
#     vertices {
#       x: 620
#       y: 9
#     }
#     vertices {
#       x: 607
#       y: 9
#     }
#   }
# }
# text_annotations {
#   description: "パート"
#   bounding_poly {
#     vertices {
#       x: 620
#       y: 1
#     }
#     vertices {
#       x: 640
#       y: 1
#     }
#     vertices {
#       x: 640
#       y: 9
#     }
#     vertices {
#       x: 620
#       y: 9
#     }
#   }
# }
# text_annotations {
#   description: ")"
#   bounding_poly {
#     vertices {
#       x: 640
#       y: 1
#     }
#     vertices {
#       x: 644
#       y: 1
#     }
#     vertices {
#       x: 644
#       y: 9
#     }
#     vertices {
#       x: 640
#       y: 9
#     }
#   }
# }
# text_annotations {
#   description: "0"
#   bounding_poly {
#     vertices {
#       x: 630
#       y: 21
#     }
#     vertices {
#       x: 634
#       y: 21
#     }
#     vertices {
#       x: 634
#       y: 28
#     }
#     vertices {
#       x: 630
#       y: 28
#     }
#   }
# }
# text_annotations {
#   description: "人"
#   bounding_poly {
#     vertices {
#       x: 635
#       y: 21
#     }
#     vertices {
#       x: 644
#       y: 21
#     }
#     vertices {
#       x: 644
#       y: 28
#     }
#     vertices {
#       x: 635
#       y: 28
#     }
#   }
# }
# text_annotations {
#   description: "設"
#   bounding_poly {
#     vertices {
#       x: 387
#       y: 39
#     }
#     vertices {
#       x: 397
#       y: 39
#     }
#     vertices {
#       x: 397
#       y: 47
#     }
#     vertices {
#       x: 387
#       y: 47
#     }
#   }
# }
# text_annotations {
#   description: "立"
#   bounding_poly {
#     vertices {
#       x: 423
#       y: 40
#     }
#     vertices {
#       x: 432
#       y: 40
#     }
#     vertices {
#       x: 432
#       y: 47
#     }
#     vertices {
#       x: 423
#       y: 47
#     }
#   }
# }
# text_annotations {
#   description: "平成"
#   bounding_poly {
#     vertices {
#       x: 440
#       y: 39
#     }
#     vertices {
#       x: 457
#       y: 39
#     }
#     vertices {
#       x: 457
#       y: 46
#     }
#     vertices {
#       x: 440
#       y: 46
#     }
#   }
# }
# text_annotations {
#   description: "31"
#   bounding_poly {
#     vertices {
#       x: 457
#       y: 39
#     }
#     vertices {
#       x: 464
#       y: 39
#     }
#     vertices {
#       x: 464
#       y: 46
#     }
#     vertices {
#       x: 457
#       y: 46
#     }
#   }
# }
# text_annotations {
#   description: "年"
#   bounding_poly {
#     vertices {
#       x: 465
#       y: 39
#     }
#     vertices {
#       x: 473
#       y: 39
#     }
#     vertices {
#       x: 473
#       y: 46
#     }
#     vertices {
#       x: 465
#       y: 46
#     }
#   }
# }
# text_annotations {
#   description: "資本"
#   bounding_poly {
#     vertices {
#       x: 513
#       y: 39
#     }
#     vertices {
#       x: 536
#       y: 39
#     }
#     vertices {
#       x: 536
#       y: 47
#     }
#     vertices {
#       x: 513
#       y: 47
#     }
#   }
# }
# text_annotations {
#   description: "金"
#   bounding_poly {
#     vertices {
#       x: 544
#       y: 39
#     }
#     vertices {
#       x: 553
#       y: 39
#     }
#     vertices {
#       x: 553
#       y: 47
#     }
#     vertices {
#       x: 544
#       y: 47
#     }
#   }
# }
# text_annotations {
#   description: "従業"
#   bounding_poly {
#     vertices {
#       x: 383
#     }
#     vertices {
#       x: 392
#     }
#     vertices {
#       x: 392
#       y: 15
#     }
#     vertices {
#       x: 383
#       y: 15
#     }
#   }
# }
# text_annotations {
#   description: "員数"
#   bounding_poly {
#     vertices {
#       x: 383
#       y: 17
#     }
#     vertices {
#       x: 392
#       y: 17
#     }
#     vertices {
#       x: 392
#       y: 33
#     }
#     vertices {
#       x: 383
#       y: 33
#     }
#   }
# }
# text_annotations {
#   description: "事"
#   bounding_poly {
#     vertices {
#       x: 383
#       y: 55
#     }
#     vertices {
#       x: 392
#       y: 55
#     }
#     vertices {
#       x: 392
#       y: 63
#     }
#     vertices {
#       x: 383
#       y: 63
#     }
#   }
# }
# text_annotations {
#   description: "内容"
#   bounding_poly {
#     vertices {
#       x: 383
#       y: 76
#     }
#     vertices {
#       x: 392
#       y: 76
#     }
#     vertices {
#       x: 392
#       y: 94
#     }
#     vertices {
#       x: 383
#       y: 94
#     }
#   }
# }
# text_annotations {
#   description: "会社"
#   bounding_poly {
#     vertices {
#       x: 383
#       y: 97
#     }
#     vertices {
#       x: 392
#       y: 97
#     }
#     vertices {
#       x: 392
#       y: 114
#     }
#     vertices {
#       x: 383
#       y: 114
#     }
#   }
# }
# text_annotations {
#   description: "の"
#   bounding_poly {
#     vertices {
#       x: 383
#       y: 115
#     }
#     vertices {
#       x: 392
#       y: 115
#     }
#     vertices {
#       x: 392
#       y: 121
#     }
#     vertices {
#       x: 383
#       y: 121
#     }
#   }
# }
# text_annotations {
#   description: "特長"
#   bounding_poly {
#     vertices {
#       x: 383
#       y: 122
#     }
#     vertices {
#       x: 392
#       y: 122
#     }
#     vertices {
#       x: 392
#       y: 138
#     }
#     vertices {
#       x: 383
#       y: 138
#     }
#   }
# }
# text_annotations {
#   description: "日本"
#   bounding_poly {
#     vertices {
#       x: 405
#       y: 61
#     }
#     vertices {
#       x: 421
#       y: 61
#     }
#     vertices {
#       x: 421
#       y: 69
#     }
#     vertices {
#       x: 405
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "の"
#   bounding_poly {
#     vertices {
#       x: 422
#       y: 61
#     }
#     vertices {
#       x: 430
#       y: 61
#     }
#     vertices {
#       x: 430
#       y: 69
#     }
#     vertices {
#       x: 422
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "インフラ"
#   bounding_poly {
#     vertices {
#       x: 430
#       y: 61
#     }
#     vertices {
#       x: 461
#       y: 61
#     }
#     vertices {
#       x: 461
#       y: 69
#     }
#     vertices {
#       x: 430
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "設備"
#   bounding_poly {
#     vertices {
#       x: 462
#       y: 61
#     }
#     vertices {
#       x: 477
#       y: 61
#     }
#     vertices {
#       x: 477
#       y: 69
#     }
#     vertices {
#       x: 462
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "を"
#   bounding_poly {
#     vertices {
#       x: 479
#       y: 61
#     }
#     vertices {
#       x: 485
#       y: 61
#     }
#     vertices {
#       x: 485
#       y: 69
#     }
#     vertices {
#       x: 479
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "手掛ける"
#   bounding_poly {
#     vertices {
#       x: 487
#       y: 61
#     }
#     vertices {
#       x: 518
#       y: 61
#     }
#     vertices {
#       x: 518
#       y: 69
#     }
#     vertices {
#       x: 487
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "大手"
#   bounding_poly {
#     vertices {
#       x: 519
#       y: 61
#     }
#     vertices {
#       x: 535
#       y: 61
#     }
#     vertices {
#       x: 535
#       y: 69
#     }
#     vertices {
#       x: 519
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "ゼネコン"
#   bounding_poly {
#     vertices {
#       x: 537
#       y: 61
#     }
#     vertices {
#       x: 569
#       y: 61
#     }
#     vertices {
#       x: 569
#       y: 69
#     }
#     vertices {
#       x: 537
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "から"
#   bounding_poly {
#     vertices {
#       x: 570
#       y: 61
#     }
#     vertices {
#       x: 594
#       y: 61
#     }
#     vertices {
#       x: 594
#       y: 69
#     }
#     vertices {
#       x: 570
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "仕事"
#   bounding_poly {
#     vertices {
#       x: 586
#       y: 61
#     }
#     vertices {
#       x: 601
#       y: 61
#     }
#     vertices {
#       x: 601
#       y: 69
#     }
#     vertices {
#       x: 586
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "を"
#   bounding_poly {
#     vertices {
#       x: 603
#       y: 61
#     }
#     vertices {
#       x: 610
#       y: 61
#     }
#     vertices {
#       x: 610
#       y: 69
#     }
#     vertices {
#       x: 603
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "頂き"
#   bounding_poly {
#     vertices {
#       x: 610
#       y: 61
#     }
#     vertices {
#       x: 625
#       y: 61
#     }
#     vertices {
#       x: 625
#       y: 69
#     }
#     vertices {
#       x: 610
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "、"
#   bounding_poly {
#     vertices {
#       x: 626
#       y: 61
#     }
#     vertices {
#       x: 629
#       y: 61
#     }
#     vertices {
#       x: 629
#       y: 69
#     }
#     vertices {
#       x: 626
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "オフ"
#   bounding_poly {
#     vertices {
#       x: 635
#       y: 61
#     }
#     vertices {
#       x: 650
#       y: 61
#     }
#     vertices {
#       x: 650
#       y: 69
#     }
#     vertices {
#       x: 635
#       y: 69
#     }
#   }
# }
# text_annotations {
#   description: "ィ"
#   bounding_poly {
#     vertices {
#       x: 405
#       y: 71
#     }
#     vertices {
#       x: 410
#       y: 71
#     }
#     vertices {
#       x: 410
#       y: 79
#     }
#     vertices {
#       x: 405
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "ス"
#   bounding_poly {
#     vertices {
#       x: 413
#       y: 71
#     }
#     vertices {
#       x: 420
#       y: 71
#     }
#     vertices {
#       x: 420
#       y: 79
#     }
#     vertices {
#       x: 413
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "から"
#   bounding_poly {
#     vertices {
#       x: 421
#       y: 71
#     }
#     vertices {
#       x: 436
#       y: 71
#     }
#     vertices {
#       x: 436
#       y: 79
#     }
#     vertices {
#       x: 421
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "図面"
#   bounding_poly {
#     vertices {
#       x: 438
#       y: 71
#     }
#     vertices {
#       x: 454
#       y: 71
#     }
#     vertices {
#       x: 454
#       y: 79
#     }
#     vertices {
#       x: 438
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "の"
#   bounding_poly {
#     vertices {
#       x: 454
#       y: 71
#     }
#     vertices {
#       x: 462
#       y: 71
#     }
#     vertices {
#       x: 462
#       y: 79
#     }
#     vertices {
#       x: 454
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "作図"
#   bounding_poly {
#     vertices {
#       x: 462
#       y: 71
#     }
#     vertices {
#       x: 478
#       y: 71
#     }
#     vertices {
#       x: 478
#       y: 79
#     }
#     vertices {
#       x: 462
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "や"
#   bounding_poly {
#     vertices {
#       x: 479
#       y: 71
#     }
#     vertices {
#       x: 486
#       y: 71
#     }
#     vertices {
#       x: 486
#       y: 79
#     }
#     vertices {
#       x: 479
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "数量"
#   bounding_poly {
#     vertices {
#       x: 486
#       y: 71
#     }
#     vertices {
#       x: 502
#       y: 71
#     }
#     vertices {
#       x: 502
#       y: 79
#     }
#     vertices {
#       x: 486
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "計算"
#   bounding_poly {
#     vertices {
#       x: 503
#       y: 71
#     }
#     vertices {
#       x: 518
#       y: 71
#     }
#     vertices {
#       x: 518
#       y: 79
#     }
#     vertices {
#       x: 503
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "など"
#   bounding_poly {
#     vertices {
#       x: 520
#       y: 71
#     }
#     vertices {
#       x: 535
#       y: 71
#     }
#     vertices {
#       x: 535
#       y: 79
#     }
#     vertices {
#       x: 520
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "を"
#   bounding_poly {
#     vertices {
#       x: 537
#       y: 71
#     }
#     vertices {
#       x: 544
#       y: 71
#     }
#     vertices {
#       x: 544
#       y: 79
#     }
#     vertices {
#       x: 537
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "行い"
#   bounding_poly {
#     vertices {
#       x: 544
#       y: 71
#     }
#     vertices {
#       x: 560
#       y: 71
#     }
#     vertices {
#       x: 560
#       y: 79
#     }
#     vertices {
#       x: 544
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "、"
#   bounding_poly {
#     vertices {
#       x: 561
#       y: 71
#     }
#     vertices {
#       x: 564
#       y: 71
#     }
#     vertices {
#       x: 564
#       y: 79
#     }
#     vertices {
#       x: 561
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "現場"
#   bounding_poly {
#     vertices {
#       x: 569
#       y: 71
#     }
#     vertices {
#       x: 585
#       y: 71
#     }
#     vertices {
#       x: 585
#       y: 79
#     }
#     vertices {
#       x: 569
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "を"
#   bounding_poly {
#     vertices {
#       x: 586
#       y: 71
#     }
#     vertices {
#       x: 592
#       y: 71
#     }
#     vertices {
#       x: 592
#       y: 79
#     }
#     vertices {
#       x: 586
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "支援"
#   bounding_poly {
#     vertices {
#       x: 594
#       y: 71
#     }
#     vertices {
#       x: 609
#       y: 71
#     }
#     vertices {
#       x: 609
#       y: 79
#     }
#     vertices {
#       x: 594
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "する"
#   bounding_poly {
#     vertices {
#       x: 610
#       y: 71
#     }
#     vertices {
#       x: 625
#       y: 71
#     }
#     vertices {
#       x: 625
#       y: 79
#     }
#     vertices {
#       x: 610
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "業務"
#   bounding_poly {
#     vertices {
#       x: 627
#       y: 71
#     }
#     vertices {
#       x: 643
#       y: 71
#     }
#     vertices {
#       x: 643
#       y: 79
#     }
#     vertices {
#       x: 627
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "を"
#   bounding_poly {
#     vertices {
#       x: 644
#       y: 71
#     }
#     vertices {
#       x: 650
#       y: 71
#     }
#     vertices {
#       x: 650
#       y: 79
#     }
#     vertices {
#       x: 644
#       y: 79
#     }
#   }
# }
# text_annotations {
#   description: "内"
#   bounding_poly {
#     vertices {
#       x: 385
#       y: 77
#     }
#     vertices {
#       x: 393
#       y: 77
#     }
#     vertices {
#       x: 393
#       y: 88
#     }
#     vertices {
#       x: 385
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "行っ"
#   bounding_poly {
#     vertices {
#       x: 404
#       y: 77
#     }
#     vertices {
#       x: 419
#       y: 77
#     }
#     vertices {
#       x: 419
#       y: 88
#     }
#     vertices {
#       x: 404
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "て"
#   bounding_poly {
#     vertices {
#       x: 421
#       y: 77
#     }
#     vertices {
#       x: 428
#       y: 77
#     }
#     vertices {
#       x: 428
#       y: 88
#     }
#     vertices {
#       x: 421
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "おり"
#   bounding_poly {
#     vertices {
#       x: 429
#       y: 77
#     }
#     vertices {
#       x: 443
#       y: 77
#     }
#     vertices {
#       x: 443
#       y: 88
#     }
#     vertices {
#       x: 429
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "ます"
#   bounding_poly {
#     vertices {
#       x: 447
#       y: 77
#     }
#     vertices {
#       x: 461
#       y: 77
#     }
#     vertices {
#       x: 461
#       y: 88
#     }
#     vertices {
#       x: 447
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "。"
#   bounding_poly {
#     vertices {
#       x: 462
#       y: 77
#     }
#     vertices {
#       x: 466
#       y: 77
#     }
#     vertices {
#       x: 466
#       y: 88
#     }
#     vertices {
#       x: 462
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "施工"
#   bounding_poly {
#     vertices {
#       x: 471
#       y: 77
#     }
#     vertices {
#       x: 486
#       y: 77
#     }
#     vertices {
#       x: 486
#       y: 88
#     }
#     vertices {
#       x: 471
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "管理"
#   bounding_poly {
#     vertices {
#       x: 486
#       y: 77
#     }
#     vertices {
#       x: 503
#       y: 77
#     }
#     vertices {
#       x: 503
#       y: 88
#     }
#     vertices {
#       x: 486
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "として"
#   bounding_poly {
#     vertices {
#       x: 504
#       y: 77
#     }
#     vertices {
#       x: 527
#       y: 77
#     }
#     vertices {
#       x: 527
#       y: 88
#     }
#     vertices {
#       x: 504
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "の"
#   bounding_poly {
#     vertices {
#       x: 528
#       y: 77
#     }
#     vertices {
#       x: 534
#       y: 77
#     }
#     vertices {
#       x: 534
#       y: 88
#     }
#     vertices {
#       x: 528
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "現場"
#   bounding_poly {
#     vertices {
#       x: 536
#       y: 77
#     }
#     vertices {
#       x: 551
#       y: 77
#     }
#     vertices {
#       x: 551
#       y: 88
#     }
#     vertices {
#       x: 536
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "の"
#   bounding_poly {
#     vertices {
#       x: 553
#       y: 77
#     }
#     vertices {
#       x: 560
#       y: 77
#     }
#     vertices {
#       x: 560
#       y: 88
#     }
#     vertices {
#       x: 553
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "仕事"
#   bounding_poly {
#     vertices {
#       x: 561
#       y: 77
#     }
#     vertices {
#       x: 576
#       y: 77
#     }
#     vertices {
#       x: 576
#       y: 88
#     }
#     vertices {
#       x: 561
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "を"
#   bounding_poly {
#     vertices {
#       x: 578
#       y: 77
#     }
#     vertices {
#       x: 585
#       y: 77
#     }
#     vertices {
#       x: 585
#       y: 88
#     }
#     vertices {
#       x: 578
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "行っ"
#   bounding_poly {
#     vertices {
#       x: 586
#       y: 77
#     }
#     vertices {
#       x: 601
#       y: 77
#     }
#     vertices {
#       x: 601
#       y: 88
#     }
#     vertices {
#       x: 586
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "て"
#   bounding_poly {
#     vertices {
#       x: 602
#       y: 77
#     }
#     vertices {
#       x: 609
#       y: 77
#     }
#     vertices {
#       x: 609
#       y: 88
#     }
#     vertices {
#       x: 602
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "い"
#   bounding_poly {
#     vertices {
#       x: 611
#       y: 77
#     }
#     vertices {
#       x: 618
#       y: 77
#     }
#     vertices {
#       x: 618
#       y: 88
#     }
#     vertices {
#       x: 611
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "ます"
#   bounding_poly {
#     vertices {
#       x: 619
#       y: 77
#     }
#     vertices {
#       x: 634
#       y: 77
#     }
#     vertices {
#       x: 634
#       y: 88
#     }
#     vertices {
#       x: 619
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "。"
#   bounding_poly {
#     vertices {
#       x: 634
#       y: 77
#     }
#     vertices {
#       x: 638
#       y: 77
#     }
#     vertices {
#       x: 638
#       y: 88
#     }
#     vertices {
#       x: 634
#       y: 88
#     }
#   }
# }
# text_annotations {
#   description: "会社"
#   bounding_poly {
#     vertices {
#       x: 404
#       y: 105
#     }
#     vertices {
#       x: 421
#       y: 105
#     }
#     vertices {
#       x: 421
#       y: 113
#     }
#     vertices {
#       x: 404
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "を"
#   bounding_poly {
#     vertices {
#       x: 421
#       y: 105
#     }
#     vertices {
#       x: 427
#       y: 105
#     }
#     vertices {
#       x: 427
#       y: 113
#     }
#     vertices {
#       x: 421
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "設立"
#   bounding_poly {
#     vertices {
#       x: 429
#       y: 105
#     }
#     vertices {
#       x: 445
#       y: 105
#     }
#     vertices {
#       x: 445
#       y: 113
#     }
#     vertices {
#       x: 429
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "し"
#   bounding_poly {
#     vertices {
#       x: 448
#       y: 105
#     }
#     vertices {
#       x: 453
#       y: 105
#     }
#     vertices {
#       x: 453
#       y: 113
#     }
#     vertices {
#       x: 448
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "て"
#   bounding_poly {
#     vertices {
#       x: 454
#       y: 105
#     }
#     vertices {
#       x: 461
#       y: 105
#     }
#     vertices {
#       x: 461
#       y: 113
#     }
#     vertices {
#       x: 454
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "浅い"
#   bounding_poly {
#     vertices {
#       x: 462
#       y: 105
#     }
#     vertices {
#       x: 479
#       y: 105
#     }
#     vertices {
#       x: 479
#       y: 113
#     }
#     vertices {
#       x: 462
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "です"
#   bounding_poly {
#     vertices {
#       x: 479
#       y: 105
#     }
#     vertices {
#       x: 494
#       y: 105
#     }
#     vertices {
#       x: 494
#       y: 113
#     }
#     vertices {
#       x: 479
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "が"
#   bounding_poly {
#     vertices {
#       x: 495
#       y: 105
#     }
#     vertices {
#       x: 502
#       y: 105
#     }
#     vertices {
#       x: 502
#       y: 113
#     }
#     vertices {
#       x: 495
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "、"
#   bounding_poly {
#     vertices {
#       x: 503
#       y: 105
#     }
#     vertices {
#       x: 506
#       y: 105
#     }
#     vertices {
#       x: 506
#       y: 113
#     }
#     vertices {
#       x: 503
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "業績"
#   bounding_poly {
#     vertices {
#       x: 511
#       y: 105
#     }
#     vertices {
#       x: 526
#       y: 105
#     }
#     vertices {
#       x: 526
#       y: 113
#     }
#     vertices {
#       x: 511
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "も"
#   bounding_poly {
#     vertices {
#       x: 528
#       y: 105
#     }
#     vertices {
#       x: 534
#       y: 105
#     }
#     vertices {
#       x: 534
#       y: 113
#     }
#     vertices {
#       x: 528
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "右肩"
#   bounding_poly {
#     vertices {
#       x: 536
#       y: 105
#     }
#     vertices {
#       x: 551
#       y: 105
#     }
#     vertices {
#       x: 551
#       y: 113
#     }
#     vertices {
#       x: 536
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "上がり"
#   bounding_poly {
#     vertices {
#       x: 553
#       y: 105
#     }
#     vertices {
#       x: 575
#       y: 105
#     }
#     vertices {
#       x: 575
#       y: 113
#     }
#     vertices {
#       x: 553
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "を"
#   bounding_poly {
#     vertices {
#       x: 578
#       y: 105
#     }
#     vertices {
#       x: 585
#       y: 105
#     }
#     vertices {
#       x: 585
#       y: 113
#     }
#     vertices {
#       x: 578
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "キープ"
#   bounding_poly {
#     vertices {
#       x: 586
#       y: 105
#     }
#     vertices {
#       x: 611
#       y: 105
#     }
#     vertices {
#       x: 611
#       y: 113
#     }
#     vertices {
#       x: 586
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "し"
#   bounding_poly {
#     vertices {
#       x: 612
#       y: 105
#     }
#     vertices {
#       x: 617
#       y: 105
#     }
#     vertices {
#       x: 617
#       y: 113
#     }
#     vertices {
#       x: 612
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "て"
#   bounding_poly {
#     vertices {
#       x: 619
#       y: 105
#     }
#     vertices {
#       x: 626
#       y: 105
#     }
#     vertices {
#       x: 626
#       y: 113
#     }
#     vertices {
#       x: 619
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "おり"
#   bounding_poly {
#     vertices {
#       x: 627
#       y: 105
#     }
#     vertices {
#       x: 640
#       y: 105
#     }
#     vertices {
#       x: 640
#       y: 113
#     }
#     vertices {
#       x: 627
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "ま"
#   bounding_poly {
#     vertices {
#       x: 644
#       y: 105
#     }
#     vertices {
#       x: 650
#       y: 105
#     }
#     vertices {
#       x: 650
#       y: 113
#     }
#     vertices {
#       x: 644
#       y: 113
#     }
#   }
# }
# text_annotations {
#   description: "す"
#   bounding_poly {
#     vertices {
#       x: 404
#       y: 115
#     }
#     vertices {
#       x: 412
#       y: 115
#     }
#     vertices {
#       x: 412
#       y: 123
#     }
#     vertices {
#       x: 404
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "。"
#   bounding_poly {
#     vertices {
#       x: 413
#       y: 115
#     }
#     vertices {
#       x: 417
#       y: 115
#     }
#     vertices {
#       x: 417
#       y: 123
#     }
#     vertices {
#       x: 413
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "人数"
#   bounding_poly {
#     vertices {
#       x: 421
#       y: 115
#     }
#     vertices {
#       x: 437
#       y: 115
#     }
#     vertices {
#       x: 437
#       y: 123
#     }
#     vertices {
#       x: 421
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "が"
#   bounding_poly {
#     vertices {
#       x: 438
#       y: 115
#     }
#     vertices {
#       x: 446
#       y: 115
#     }
#     vertices {
#       x: 446
#       y: 123
#     }
#     vertices {
#       x: 438
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "少ない"
#   bounding_poly {
#     vertices {
#       x: 446
#       y: 115
#     }
#     vertices {
#       x: 470
#       y: 115
#     }
#     vertices {
#       x: 470
#       y: 123
#     }
#     vertices {
#       x: 446
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "から"
#   bounding_poly {
#     vertices {
#       x: 471
#       y: 115
#     }
#     vertices {
#       x: 486
#       y: 115
#     }
#     vertices {
#       x: 486
#       y: 123
#     }
#     vertices {
#       x: 471
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "こそ"
#   bounding_poly {
#     vertices {
#       x: 488
#       y: 115
#     }
#     vertices {
#       x: 502
#       y: 115
#     }
#     vertices {
#       x: 502
#       y: 123
#     }
#     vertices {
#       x: 488
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "自分"
#   bounding_poly {
#     vertices {
#       x: 504
#       y: 115
#     }
#     vertices {
#       x: 519
#       y: 115
#     }
#     vertices {
#       x: 519
#       y: 123
#     }
#     vertices {
#       x: 504
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "の"
#   bounding_poly {
#     vertices {
#       x: 520
#       y: 115
#     }
#     vertices {
#       x: 526
#       y: 115
#     }
#     vertices {
#       x: 526
#       y: 123
#     }
#     vertices {
#       x: 520
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "意見"
#   bounding_poly {
#     vertices {
#       x: 528
#       y: 115
#     }
#     vertices {
#       x: 543
#       y: 115
#     }
#     vertices {
#       x: 543
#       y: 123
#     }
#     vertices {
#       x: 528
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "が"
#   bounding_poly {
#     vertices {
#       x: 545
#       y: 115
#     }
#     vertices {
#       x: 553
#       y: 115
#     }
#     vertices {
#       x: 553
#       y: 123
#     }
#     vertices {
#       x: 545
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "言い"
#   bounding_poly {
#     vertices {
#       x: 553
#       y: 115
#     }
#     vertices {
#       x: 568
#       y: 115
#     }
#     vertices {
#       x: 568
#       y: 123
#     }
#     vertices {
#       x: 553
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "やすい"
#   bounding_poly {
#     vertices {
#       x: 569
#       y: 115
#     }
#     vertices {
#       x: 594
#       y: 115
#     }
#     vertices {
#       x: 594
#       y: 123
#     }
#     vertices {
#       x: 569
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "環境"
#   bounding_poly {
#     vertices {
#       x: 594
#       y: 115
#     }
#     vertices {
#       x: 609
#       y: 115
#     }
#     vertices {
#       x: 609
#       y: 123
#     }
#     vertices {
#       x: 594
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "です"
#   bounding_poly {
#     vertices {
#       x: 610
#       y: 115
#     }
#     vertices {
#       x: 626
#       y: 115
#     }
#     vertices {
#       x: 626
#       y: 123
#     }
#     vertices {
#       x: 610
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "。"
#   bounding_poly {
#     vertices {
#       x: 626
#       y: 115
#     }
#     vertices {
#       x: 630
#       y: 115
#     }
#     vertices {
#       x: 630
#       y: 123
#     }
#     vertices {
#       x: 626
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "一緒"
#   bounding_poly {
#     vertices {
#       x: 635
#       y: 115
#     }
#     vertices {
#       x: 651
#       y: 115
#     }
#     vertices {
#       x: 651
#       y: 123
#     }
#     vertices {
#       x: 635
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "に"
#   bounding_poly {
#     vertices {
#       x: 405
#       y: 125
#     }
#     vertices {
#       x: 413
#       y: 125
#     }
#     vertices {
#       x: 413
#       y: 132
#     }
#     vertices {
#       x: 405
#       y: 132
#     }
#   }
# }
# text_annotations {
#   description: "会社"
#   bounding_poly {
#     vertices {
#       x: 413
#       y: 125
#     }
#     vertices {
#       x: 429
#       y: 125
#     }
#     vertices {
#       x: 429
#       y: 132
#     }
#     vertices {
#       x: 413
#       y: 132
#     }
#   }
# }
# text_annotations {
#   description: "を"
#   bounding_poly {
#     vertices {
#       x: 430
#       y: 125
#     }
#     vertices {
#       x: 437
#       y: 125
#     }
#     vertices {
#       x: 437
#       y: 132
#     }
#     vertices {
#       x: 430
#       y: 132
#     }
#   }
# }
# text_annotations {
#   description: "作っ"
#   bounding_poly {
#     vertices {
#       x: 437
#       y: 125
#     }
#     vertices {
#       x: 452
#       y: 125
#     }
#     vertices {
#       x: 452
#       y: 132
#     }
#     vertices {
#       x: 437
#       y: 132
#     }
#   }
# }
# text_annotations {
#   description: "て"
#   bounding_poly {
#     vertices {
#       x: 454
#       y: 125
#     }
#     vertices {
#       x: 461
#       y: 125
#     }
#     vertices {
#       x: 461
#       y: 132
#     }
#     vertices {
#       x: 454
#       y: 132
#     }
#   }
# }
# text_annotations {
#   description: "いける"
#   bounding_poly {
#     vertices {
#       x: 462
#       y: 125
#     }
#     vertices {
#       x: 486
#       y: 125
#     }
#     vertices {
#       x: 486
#       y: 132
#     }
#     vertices {
#       x: 462
#       y: 132
#     }
#   }
# }
# text_annotations {
#   description: "の"
#   bounding_poly {
#     vertices {
#       x: 487
#       y: 125
#     }
#     vertices {
#       x: 494
#       y: 125
#     }
#     vertices {
#       x: 494
#       y: 132
#     }
#     vertices {
#       x: 487
#       y: 132
#     }
#   }
# }
# text_annotations {
#   description: "が"
#   bounding_poly {
#     vertices {
#       x: 495
#       y: 125
#     }
#     vertices {
#       x: 502
#       y: 125
#     }
#     vertices {
#       x: 502
#       y: 132
#     }
#     vertices {
#       x: 495
#       y: 132
#     }
#   }
# }
# text_annotations {
#   description: "特徴"
#   bounding_poly {
#     vertices {
#       x: 503
#       y: 125
#     }
#     vertices {
#       x: 519
#       y: 125
#     }
#     vertices {
#       x: 519
#       y: 132
#     }
#     vertices {
#       x: 503
#       y: 132
#     }
#   }
# }
# text_annotations {
#   description: "です"
#   bounding_poly {
#     vertices {
#       x: 519
#       y: 125
#     }
#     vertices {
#       x: 535
#       y: 125
#     }
#     vertices {
#       x: 535
#       y: 132
#     }
#     vertices {
#       x: 519
#       y: 132
#     }
#   }
# }
# text_annotations {
#   description: "。"
#   bounding_poly {
#     vertices {
#       x: 535
#       y: 125
#     }
#     vertices {
#       x: 538
#       y: 125
#     }
#     vertices {
#       x: 538
#       y: 132
#     }
#     vertices {
#       x: 535
#       y: 132
#     }
#   }
# }
# full_text_annotation {
#   pages {
#     property {
#       detected_languages {
#         language_code: "ja"
#         confidence: 0.811944067
#       }
#     }
#     width: 655
#     height: 156
#     blocks {
#       bounding_box {
#         vertices {
#           x: 28
#           y: 3
#         }
#         vertices {
#           x: 111
#           y: 3
#         }
#         vertices {
#           x: 111
#           y: 31
#         }
#         vertices {
#           x: 28
#           y: 31
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 28
#             y: 3
#           }
#           vertices {
#             x: 111
#             y: 3
#           }
#           vertices {
#             x: 111
#             y: 31
#           }
#           vertices {
#             x: 28
#             y: 31
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 28
#               y: 3
#             }
#             vertices {
#               x: 78
#               y: 3
#             }
#             vertices {
#               x: 78
#               y: 10
#             }
#             vertices {
#               x: 28
#               y: 10
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 28
#                 y: 4
#               }
#               vertices {
#                 x: 33
#                 y: 4
#               }
#               vertices {
#                 x: 33
#                 y: 10
#               }
#               vertices {
#                 x: 28
#                 y: 10
#               }
#             }
#             text: "カ"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 33
#                 y: 3
#               }
#               vertices {
#                 x: 40
#                 y: 3
#               }
#               vertices {
#                 x: 40
#                 y: 9
#               }
#               vertices {
#                 x: 33
#                 y: 9
#               }
#             }
#             text: "ブ"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 40
#                 y: 3
#               }
#               vertices {
#                 x: 46
#                 y: 3
#               }
#               vertices {
#                 x: 46
#                 y: 9
#               }
#               vertices {
#                 x: 40
#                 y: 9
#               }
#             }
#             text: "シ"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 46
#                 y: 3
#               }
#               vertices {
#                 x: 52
#                 y: 3
#               }
#               vertices {
#                 x: 52
#                 y: 9
#               }
#               vertices {
#                 x: 46
#                 y: 9
#               }
#             }
#             text: "キ"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 53
#                 y: 3
#               }
#               vertices {
#                 x: 59
#                 y: 3
#               }
#               vertices {
#                 x: 59
#                 y: 9
#               }
#               vertices {
#                 x: 53
#                 y: 9
#               }
#             }
#             text: "ガ"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 59
#                 y: 3
#               }
#               vertices {
#                 x: 64
#                 y: 3
#               }
#               vertices {
#                 x: 64
#                 y: 9
#               }
#               vertices {
#                 x: 59
#                 y: 9
#               }
#             }
#             text: "イ"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 66
#                 y: 3
#               }
#               vertices {
#                 x: 71
#                 y: 3
#               }
#               vertices {
#                 x: 71
#                 y: 9
#               }
#               vertices {
#                 x: 66
#                 y: 9
#               }
#             }
#             text: "シ"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 73
#                 y: 3
#               }
#               vertices {
#                 x: 78
#                 y: 3
#               }
#               vertices {
#                 x: 78
#                 y: 9
#               }
#               vertices {
#                 x: 73
#                 y: 9
# ...
#               x: 626
#               y: 123
#             }
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 626
#                 y: 115
#               }
#               vertices {
#                 x: 630
#                 y: 115
#               }
#               vertices {
#                 x: 630
#                 y: 123
#               }
#               vertices {
#                 x: 626
#                 y: 123
#               }
#             }
#             text: "。"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 635
#               y: 115
#             }
#             vertices {
#               x: 651
#               y: 115
#             }
#             vertices {
#               x: 651
#               y: 123
#             }
#             vertices {
#               x: 635
#               y: 123
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 635
#                 y: 115
#               }
#               vertices {
#                 x: 642
#                 y: 115
#               }
#               vertices {
#                 x: 642
#                 y: 123
#               }
#               vertices {
#                 x: 635
#                 y: 123
#               }
#             }
#             text: "一"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: EOL_SURE_SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 643
#                 y: 115
#               }
#               vertices {
#                 x: 651
#                 y: 115
#               }
#               vertices {
#                 x: 651
#                 y: 123
#               }
#               vertices {
#                 x: 643
#                 y: 123
#               }
#             }
#             text: "緒"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 405
#               y: 125
#             }
#             vertices {
#               x: 413
#               y: 125
#             }
#             vertices {
#               x: 413
#               y: 132
#             }
#             vertices {
#               x: 405
#               y: 132
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 405
#                 y: 125
#               }
#               vertices {
#                 x: 413
#                 y: 125
#               }
#               vertices {
#                 x: 413
#                 y: 132
#               }
#               vertices {
#                 x: 405
#                 y: 132
#               }
#             }
#             text: "に"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 413
#               y: 125
#             }
#             vertices {
#               x: 429
#               y: 125
#             }
#             vertices {
#               x: 429
#               y: 132
#             }
#             vertices {
#               x: 413
#               y: 132
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 413
#                 y: 125
#               }
#               vertices {
#                 x: 421
#                 y: 125
#               }
#               vertices {
#                 x: 421
#                 y: 132
#               }
#               vertices {
#                 x: 413
#                 y: 132
#               }
#             }
#             text: "会"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 421
#                 y: 125
#               }
#               vertices {
#                 x: 429
#                 y: 125
#               }
#               vertices {
#                 x: 429
#                 y: 132
#               }
#               vertices {
#                 x: 421
#                 y: 132
#               }
#             }
#             text: "社"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 430
#               y: 125
#             }
#             vertices {
#               x: 437
#               y: 125
#             }
#             vertices {
#               x: 437
#               y: 132
#             }
#             vertices {
#               x: 430
#               y: 132
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 430
#                 y: 125
#               }
#               vertices {
#                 x: 437
#                 y: 125
#               }
#               vertices {
#                 x: 437
#                 y: 132
#               }
#               vertices {
#                 x: 430
#                 y: 132
#               }
#             }
#             text: "を"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 437
#               y: 125
#             }
#             vertices {
#               x: 452
#               y: 125
#             }
#             vertices {
#               x: 452
#               y: 132
#             }
#             vertices {
#               x: 437
#               y: 132
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 437
#                 y: 125
#               }
#               vertices {
#                 x: 445
#                 y: 125
#               }
#               vertices {
#                 x: 445
#                 y: 132
#               }
#               vertices {
#                 x: 437
#                 y: 132
#               }
#             }
#             text: "作"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 447
#                 y: 125
#               }
#               vertices {
#                 x: 452
#                 y: 125
#               }
#               vertices {
#                 x: 452
#                 y: 132
#               }
#               vertices {
#                 x: 447
#                 y: 132
#               }
#             }
#             text: "っ"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 454
#               y: 125
#             }
#             vertices {
#               x: 461
#               y: 125
#             }
#             vertices {
#               x: 461
#               y: 132
#             }
#             vertices {
#               x: 454
#               y: 132
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 454
#                 y: 125
#               }
#               vertices {
#                 x: 461
#                 y: 125
#               }
#               vertices {
#                 x: 461
#                 y: 132
#               }
#               vertices {
#                 x: 454
#                 y: 132
#               }
#             }
#             text: "て"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 462
#               y: 125
#             }
#             vertices {
#               x: 486
#               y: 125
#             }
#             vertices {
#               x: 486
#               y: 132
#             }
#             vertices {
#               x: 462
#               y: 132
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 462
#                 y: 125
#               }
#               vertices {
#                 x: 470
#                 y: 125
#               }
#               vertices {
#                 x: 470
#                 y: 132
#               }
#               vertices {
#                 x: 462
#                 y: 132
#               }
#             }
#             text: "い"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 471
#                 y: 125
#               }
#               vertices {
#                 x: 479
#                 y: 125
#               }
#               vertices {
#                 x: 479
#                 y: 132
#               }
#               vertices {
#                 x: 471
#                 y: 132
#               }
#             }
#             text: "け"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 479
#                 y: 125
#               }
#               vertices {
#                 x: 486
#                 y: 125
#               }
#               vertices {
#                 x: 486
#                 y: 132
#               }
#               vertices {
#                 x: 479
#                 y: 132
#               }
#             }
#             text: "る"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 487
#               y: 125
#             }
#             vertices {
#               x: 494
#               y: 125
#             }
#             vertices {
#               x: 494
#               y: 132
#             }
#             vertices {
#               x: 487
#               y: 132
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 487
#                 y: 125
#               }
#               vertices {
#                 x: 494
#                 y: 125
#               }
#               vertices {
#                 x: 494
#                 y: 132
#               }
#               vertices {
#                 x: 487
#                 y: 132
#               }
#             }
#             text: "の"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 495
#               y: 125
#             }
#             vertices {
#               x: 502
#               y: 125
#             }
#             vertices {
#               x: 502
#               y: 132
#             }
#             vertices {
#               x: 495
#               y: 132
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 495
#                 y: 125
#               }
#               vertices {
#                 x: 502
#                 y: 125
#               }
#               vertices {
#                 x: 502
#                 y: 132
#               }
#               vertices {
#                 x: 495
#                 y: 132
#               }
#             }
#             text: "が"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 503
#               y: 125
#             }
#             vertices {
#               x: 519
#               y: 125
#             }
#             vertices {
#               x: 519
#               y: 132
#             }
#             vertices {
#               x: 503
#               y: 132
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 503
#                 y: 125
#               }
#               vertices {
#                 x: 511
#                 y: 125
#               }
#               vertices {
#                 x: 511
#                 y: 132
#               }
#               vertices {
#                 x: 503
#                 y: 132
#               }
#             }
#             text: "特"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 512
#                 y: 125
#               }
#               vertices {
#                 x: 519
#                 y: 125
#               }
#               vertices {
#                 x: 519
#                 y: 132
#               }
#               vertices {
#                 x: 512
#                 y: 132
#               }
#             }
#             text: "徴"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 519
#               y: 125
#             }
#             vertices {
#               x: 535
#               y: 125
#             }
#             vertices {
#               x: 535
#               y: 132
#             }
#             vertices {
#               x: 519
#               y: 132
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 519
#                 y: 125
#               }
#               vertices {
#                 x: 527
#                 y: 125
#               }
#               vertices {
#                 x: 527
#                 y: 132
#               }
#               vertices {
#                 x: 519
#                 y: 132
#               }
#             }
#             text: "で"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 528
#                 y: 125
#               }
#               vertices {
#                 x: 535
#                 y: 125
#               }
#               vertices {
#                 x: 535
#                 y: 132
#               }
#               vertices {
#                 x: 528
#                 y: 132
#               }
#             }
#             text: "す"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ja"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 535
#               y: 125
#             }
#             vertices {
#               x: 538
#               y: 125
#             }
#             vertices {
#               x: 538
#               y: 132
#             }
#             vertices {
#               x: 535
#               y: 132
#             }
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 535
#                 y: 125
#               }
#               vertices {
#                 x: 538
#                 y: 125
#               }
#               vertices {
#                 x: 538
#                 y: 132
#               }
#               vertices {
#                 x: 535
#                 y: 132
#               }
#             }
#             text: "。"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#   }
#   text: "カブシキガイシャ ソウケン\n株式会社 惣建\n所\n名\n所\n〒573-1106\n大阪府枚方市町楠葉1丁目17-10-203\n在\n地\n京阪 樟葉駅 から 徒歩1分\n代表者名 代表取締役\n法人番号\n4120001219359\n東野想平\nホームページ\n企業全体\n就菜場所\n2人\n2人\n(うち女性)\n人\n(うちパート)\n0人\n設\n立平成31年\n資本金\n従業員数 事内容 会社の特長\n日本のインフラ設備を手掛ける大手ゼネコンから仕事を頂き、 オフ\nィスから図面の作図や数量計算などを行い、 現場を支援する業務を\n内行っております。 施工管理としての現場の仕事を行っています。\n会社を設立して浅いですが、 業績も右肩上がりをキープしておりま\nす。人数が少ないからこそ自分の意見が言いやすい環境です。 一緒\nに会社を作っていけるのが特徴です。"
# }

# %%
import json
def load_template_frame(jsonTemplate_path):


    block_shapes = None
    template_infos = []

    with open(jsonTemplate_path, 'r') as json_file:
        data = json.load(json_file)
        block_shapes = data['shapes']

    for cur_bk in (block_shapes):
        label = cur_bk['label']
        points = cur_bk['points']
        x, y, x2, y2 = int(points[0][0]), int(points[0][1]), int(points[1][0]), int(points[1][1])

        template_infos.append([label, x, y, x2, y2])
    return template_infos



jsonTemplate_path = os.getcwd()+"/template/block_1.json"
template_infos = load_template_frame(jsonTemplate_path)
print(template_infos)
# Out:
# [['1b_01', 1, 0, 47, 110], ['1b_02', 47, 0, 874, 31], ['1b_03', 48, 30, 872, 110], ['1b_04', 874, 2, 912, 76], ['1b_05', 910, 1, 1053, 31], ['1b_06', 911, 30, 1054, 75], ['1b_07', 1055, 1, 1201, 31], ['1b_08', 1054, 32, 1201, 75], ['1b_09', 1203, 1, 1349, 32], ['1b_10', 1203, 32, 1348, 77], ['1b_11', 1349, 0, 1498, 31], ['1b_12', 1498, 77, 1349, 30], ['1b_13', 874, 75, 995, 114], ['1b_14', 998, 75, 1158, 111], ['1b_15', 1158, 75, 1279, 112], ['1b_16', 1280, 76, 1498, 114], ['1b_17', 0, 109, 46, 259], ['1b_18', 47, 110, 873, 262], ['1b_19', 912, 207, 874, 113], ['1b_20', 914, 113, 1498, 208], ['1b_21', 873, 208, 911, 299], ['1b_22', 912, 207, 1498, 301], ['1b_23', 1, 259, 122, 297], ['1b_24', 124, 261, 872, 300], ['1b_25', 1, 297, 123, 334], ['1b_26', 123, 297, 323, 335], ['1b_27', 324, 299, 459, 335], ['1b_28', 460, 299, 1499, 335]]

# %%
def load_xmlResponsesText(response):
        responseText_infos = []
        document = response.full_text_annotation
        for page in document.pages:
            for block in page.blocks:
                for paragraph in block.paragraphs:
                    for word in paragraph.words:
                        for symbol in word.symbols:
                            bbox = symbol.bounding_box
                            xmin = bbox.vertices[0].x
                            ymin = bbox.vertices[0].y
                            xmax = bbox.vertices[2].x
                            ymax = bbox.vertices[2].y
                            xcenter = (xmin + xmax) / 2
                            ycenter = (ymin + ymax) / 2

                            text = symbol.text
                            responseText_infos.append([text, xcenter, ycenter])
        return responseText_infos

# %%
responseText_infos = load_xmlResponsesText(response)
responseText_infos
# Out:
# [['カ', 30.5, 7.0],
#  ['ブ', 36.5, 6.0],
#  ['シ', 43.0, 6.0],
#  ['キ', 49.0, 6.0],
#  ['ガ', 56.0, 6.0],
#  ['イ', 61.5, 6.0],
#  ['シ', 68.5, 6.0],
#  ['ャ', 75.5, 6.0],
#  ['ソ', 87.0, 6.0],
#  ['ウ', 94.5, 6.0],
#  ['ケ', 101.5, 6.0],
#  ['ン', 108.0, 6.0],
#  ['株', 32.5, 26.5],
#  ['式', 41.0, 26.5],
#  ['会', 50.0, 26.5],
#  ['社', 60.0, 26.5],
#  ['惣', 78.5, 26.5],
#  ['建', 88.0, 26.5],
#  ['所', 9.0, 32.0],
#  ['名', 8.0, 43.0],
#  ['所', 8.5, 63.0],
#  ['〒', 32.0, 68.0],
#  ['5', 40.0, 67.0],
#  ['7', 44.5, 67.0],
#  ['3', 49.0, 67.0],
#  ['-', 55.0, 67.0],
#  ['1', 60.0, 67.0],
#  ['1', 64.0, 67.0],
#  ['0', 69.0, 67.0],
#  ['6', 73.0, 67.0],
#  ['大', 31.5, 77.5],
#  ['阪', 41.0, 77.5],
#  ['府', 51.0, 77.5],
#  ['枚', 59.0, 77.5],
#  ['方', 69.0, 77.5],
#  ['市', 79.0, 77.5],
#  ['町', 87.5, 77.5],
#  ['楠', 96.0, 77.5],
#  ['葉', 106.0, 77.5],
#  ['1', 116.0, 77.5],
#  ['丁', 125.0, 77.5],
#  ['目', 135.0, 77.5],
#  ['1', 144.0, 77.5],
#  ['7', 153.5, 77.5],
#  ['-', 164.0, 77.5],
#  ['1', 172.5, 77.5],
#  ['0', 182.0, 77.5],
#  ['-', 190.5, 77.5],
#  ['2', 200.5, 77.5],
#  ['0', 210.0, 77.5],
#  ['3', 219.0, 77.5],
#  ['在', 8.5, 85.5],
#  ['地', 9.0, 109.5],
#  ['京', 32.0, 105.5],
#  ['阪', 41.0, 105.5],
#  ['樟', 58.5, 105.5],
#  ['葉', 68.5, 105.5],
#  ['駅', 79.0, 105.5],
#  ['か', 98.5, 105.5],
#  ['ら', 107.0, 105.5],
#  ['徒', 126.0, 105.5],
#  ['歩', 135.0, 105.5],
#  ['1', 142.0, 105.5],
#  ['分', 149.5, 105.5],
#  ['代', 10.0, 131.0],
#  ['表', 19.5, 131.0],
#  ['者', 30.5, 131.0],
#  ['名', 41.0, 131.0],
#  ['代', 63.0, 130.5],
#  ['表', 70.5, 130.5],
#  ['取', 79.0, 130.5],
#  ['締', 87.5, 130.5],
#  ['役', 95.5, 130.5],
#  ['法', 10.0, 148.5],
#  ['人', 21.0, 148.5],
#  ['番', 31.5, 148.5],
#  ['号', 42.0, 148.5],
#  ['4', 60.5, 148.5],
#  ['1', 64.5, 148.5],
#  ['2', 68.0, 148.5],
#  ['0', 73.0, 148.5],
#  ['0', 77.0, 148.5],
#  ['0', 81.0, 148.5],
#  ['1', 85.5, 148.5],
#  ['2', 89.0, 148.5],
#  ['1', 93.5, 148.5],
#  ['9', 97.0, 148.5],
#  ['3', 101.0, 148.5],
#  ['5', 105.5, 148.5],
#  ['9', 110.0, 148.5],
#  ['東', 210.0, 131.0],
#  ['野', 219.0, 131.0],
#  ['想', 235.0, 131.0],
#  ['平', 243.0, 131.0],
#  ['ホ', 149.5, 148.0],
#  ['ー', 158.5, 148.0],
#  ['ム', 167.0, 148.0],
#  ['ペ', 175.5, 148.0],
#  ['ー', 183.0, 148.0],
#  ['ジ', 192.0, 148.0],
#  ['企', 414.0, 6.0],
#  ['業', 423.0, 5.0],
#  ['全', 433.0, 5.0],
#  ['体', 442.5, 5.0],
#  ['就', 479.5, 6.0],
#  ['菜', 489.5, 6.0],
#  ['場', 498.5, 6.0],
#  ['所', 508.5, 6.0],
#  ['2', 436.0, 24.0],
#  ['人', 443.5, 24.0],
#  ['2', 501.0, 24.0],
#  ['人', 508.0, 24.0],
#  ['(', 541.0, 6.0],
#  ['う', 547.0, 6.0],
#  ['ち', 554.0, 6.0],
#  ['女', 563.0, 6.0],
#  ['性', 571.5, 6.0],
#  [')', 576.5, 6.0],
#  ['人', 572.5, 23.5],
#  ['(', 607.0, 6.0],
#  ['う', 610.0, 5.0],
#  ['ち', 616.5, 5.0],
#  ['パ', 625.0, 5.0],
#  ['ー', 628.5, 5.0],
#  ['ト', 637.5, 5.0],
#  [')', 642.0, 5.0],
#  ['0', 632.0, 24.5],
#  ['人', 639.5, 24.5],
#  ['設', 392.0, 43.0],
#  ['立', 427.5, 43.5],
#  ['平', 444.0, 42.5],
#  ['成', 452.5, 42.5],
#  ['3', 458.5, 42.5],
#  ['1', 463.0, 42.5],
#  ['年', 469.0, 42.5],
#  ['資', 517.0, 43.0],
#  ['本', 531.5, 43.0],
#  ['金', 548.5, 43.0],
#  ['従', 387.5, 4.5],
#  ['業', 387.5, 11.5],
#  ['員', 387.5, 21.0],
#  ['数', 387.5, 29.0],
#  ['事', 387.5, 59.0],
#  ['内', 387.5, 80.0],
#  ['容', 387.5, 90.0],
#  ['会', 387.5, 100.5],
#  ['社', 387.5, 110.0],
#  ['の', 387.5, 118.0],
#  ['特', 387.5, 126.0],
#  ['長', 387.5, 134.5],
#  ['日', 408.0, 65.0],
#  ['本', 417.0, 65.0],
#  ['の', 426.0, 65.0],
#  ['イ', 433.0, 65.0],
#  ['ン', 441.5, 65.0],
#  ['フ', 450.0, 65.0],
#  ['ラ', 457.5, 65.0],
#  ['設', 466.0, 65.0],
#  ['備', 473.5, 65.0],
#  ['を', 482.0, 65.0],
#  ['手', 490.5, 65.0],
#  ['掛', 499.0, 65.0],
#  ['け', 507.5, 65.0],
#  ['る', 515.0, 65.0],
#  ['大', 523.0, 65.0],
#  ['手', 531.5, 65.0],
#  ['ゼ', 540.5, 65.0],
#  ['ネ', 547.5, 65.0],
#  ['コ', 556.0, 65.0],
#  ['ン', 565.5, 65.0],
#  ['か', 575.0, 65.0],
#  ['ら', 586.5, 65.0],
#  ['仕', 589.5, 65.0],
#  ['事', 597.0, 65.0],
#  ['を', 606.5, 65.0],
#  ['頂', 613.5, 65.0],
#  ['き', 622.0, 65.0],
#  ['、', 627.5, 65.0],
#  ['オ', 638.5, 65.0],
#  ['フ', 647.0, 65.0],
#  ['ィ', 407.5, 75.0],
#  ['ス', 416.5, 75.0],
#  ['か', 426.5, 75.0],
#  ['ら', 433.0, 75.0],
#  ['図', 441.5, 75.0],
#  ['面', 450.0, 75.0],
#  ['の', 458.0, 75.0],
#  ['作', 466.0, 75.0],
#  ['図', 474.5, 75.0],
#  ['や', 482.5, 75.0],
#  ['数', 490.0, 75.0],
#  ['量', 498.5, 75.0],
#  ['計', 507.0, 75.0],
#  ['算', 514.5, 75.0],
#  ['な', 523.5, 75.0],
#  ['ど', 532.0, 75.0],
#  ['を', 540.5, 75.0],
#  ['行', 548.0, 75.0],
#  ['い', 556.5, 75.0],
#  ['、', 562.5, 75.0],
#  ['現', 572.5, 75.0],
#  ['場', 581.5, 75.0],
#  ['を', 589.0, 75.0],
#  ['支', 597.5, 75.0],
#  ['援', 605.5, 75.0],
#  ['す', 613.5, 75.0],
#  ['る', 622.5, 75.0],
#  ['業', 631.0, 75.0],
#  ['務', 639.0, 75.0],
#  ['を', 647.0, 75.0],
#  ['内', 389.0, 82.5],
#  ['行', 408.5, 82.5],
#  ['っ', 416.5, 82.5],
#  ['て', 424.5, 82.5],
#  ['お', 432.5, 82.5],
#  ['り', 440.5, 82.5],
#  ['ま', 450.0, 82.5],
#  ['す', 457.5, 82.5],
#  ['。', 464.0, 82.5],
#  ['施', 474.0, 82.5],
#  ['工', 482.5, 82.5],
#  ['管', 489.5, 82.5],
#  ['理', 499.0, 82.5],
#  ['と', 506.5, 82.5],
#  ['し', 515.5, 82.5],
#  ['て', 523.5, 82.5],
#  ['の', 531.0, 82.5],
#  ['現', 539.5, 82.5],
#  ['場', 547.5, 82.5],
#  ['の', 556.5, 82.5],
#  ['仕', 564.5, 82.5],
#  ['事', 572.5, 82.5],
#  ['を', 581.5, 82.5],
#  ['行', 590.0, 82.5],
#  ['っ', 598.0, 82.5],
#  ['て', 605.5, 82.5],
#  ['い', 614.5, 82.5],
#  ['ま', 622.5, 82.5],
#  ['す', 630.5, 82.5],
#  ['。', 636.0, 82.5],
#  ['会', 408.0, 109.0],
#  ['社', 417.0, 109.0],
#  ['を', 424.0, 109.0],
#  ['設', 432.5, 109.0],
#  ['立', 441.0, 109.0],
#  ['し', 450.5, 109.0],
#  ['て', 457.5, 109.0],
#  ['浅', 466.0, 109.0],
#  ['い', 475.0, 109.0],
#  ['で', 482.5, 109.0],
#  ['す', 490.5, 109.0],
#  ['が', 498.5, 109.0],
#  ['、', 504.5, 109.0],
#  ['業', 514.5, 109.0],
#  ['績', 522.5, 109.0],
#  ['も', 531.0, 109.0],
#  ['右', 539.5, 109.0],
#  ['肩', 547.5, 109.0],
#  ['上', 556.5, 109.0],
#  ['が', 564.5, 109.0],
#  ['り', 572.5, 109.0],
#  ['を', 581.5, 109.0],
#  ['キ', 590.0, 109.0],
#  ['ー', 597.5, 109.0],
#  ['プ', 606.5, 109.0],
#  ['し', 614.5, 109.0],
#  ['て', 622.5, 109.0],
#  ['お', 630.5, 109.0],
#  ['り', 638.0, 109.0],
#  ['ま', 647.0, 109.0],
#  ['す', 408.0, 119.0],
#  ['。', 415.0, 119.0],
#  ['人', 424.5, 119.0],
#  ['数', 433.0, 119.0],
#  ['が', 442.0, 119.0],
#  ['少', 450.0, 119.0],
#  ['な', 458.0, 119.0],
#  ['い', 466.0, 119.0],
#  ['か', 475.0, 119.0],
#  ['ら', 483.0, 119.0],
#  ['こ', 490.5, 119.0],
#  ['そ', 498.5, 119.0],
#  ['自', 507.0, 119.0],
#  ['分', 515.0, 119.0],
#  ['の', 523.0, 119.0],
#  ['意', 531.5, 119.0],
#  ['見', 539.5, 119.0],
#  ['が', 549.0, 119.0],
#  ['言', 557.0, 119.0],
#  ['い', 564.5, 119.0],
#  ['や', 573.0, 119.0],
#  ['す', 580.5, 119.0],
#  ['い', 590.0, 119.0],
#  ['環', 597.5, 119.0],
#  ['境', 605.0, 119.0],
#  ['で', 613.5, 119.0],
#  ['す', 622.5, 119.0],
#  ['。', 628.0, 119.0],
#  ['一', 638.5, 119.0],
#  ['緒', 647.0, 119.0],
#  ['に', 409.0, 128.5],
#  ['会', 417.0, 128.5],
#  ['社', 425.0, 128.5],
#  ['を', 433.5, 128.5],
#  ['作', 441.0, 128.5],
#  ['っ', 449.5, 128.5],
#  ['て', 457.5, 128.5],
#  ['い', 466.0, 128.5],
#  ['け', 475.0, 128.5],
#  ['る', 482.5, 128.5],
#  ['の', 490.5, 128.5],
#  ['が', 498.5, 128.5],
#  ['特', 507.0, 128.5],
#  ['徴', 515.5, 128.5],
#  ['で', 523.0, 128.5],
#  ['す', 531.5, 128.5],
#  ['。', 536.5, 128.5]]

# %%
def match_Template(template_infos,responseText_infos):
    result_dict = {}
    for bbox in template_infos:
        label, xmin, ymin, xmax, ymax = bbox[0], bbox[1], bbox[2], bbox[3], bbox[4]
        texts = ''
        for text_info in responseText_infos:
            text = text_info[0]
            xcenter = text_info[1]
            ycenter = text_info[2]
            if xmin <= xcenter <= xmax and ymin <= ycenter <= ymax:
                texts += text
            result_dict[label] = str(texts)

    
    return  result_dict
result_dict = match_Template(template_infos,responseText_infos)
(result_dict)
# Out:
# {'1b_01': 'カブシ株式所名所〒57大阪在地京阪',
#  '1b_02': 'キガイシャソウケン会社惣建企業全体就菜場所2人2人(うち女性)人(うちパート)0人従業員数',
#  '1b_03': '3-1106府枚方市町楠葉1丁目17-10-203樟葉駅から徒歩1分設立平成31年資本金事内容会社日本のインフラ設備を手掛ける大手ゼネコンから仕事を頂き、オフィスから図面の作図や数量計算などを行い、現場を支援する業務を内行っております。施工管理としての現場の仕事を行っています。会社を設立して浅いですが、業績も右肩上がりをキープしておりま',
#  '1b_04': '',
#  '1b_05': '',
#  '1b_06': '',
#  '1b_07': '',
#  '1b_08': '',
#  '1b_09': '',
#  '1b_10': '',
#  '1b_11': '',
#  '1b_12': '',
#  '1b_13': '',
#  '1b_14': '',
#  '1b_15': '',
#  '1b_16': '',
#  '1b_17': '地代表者名法人番号',
#  '1b_18': '代表取締役4120001219359東野想平ホームページ社の特長す。人数が少ないからこそ自分の意見が言いやすい環境です。一緒に会社を作っていけるのが特徴です。',
#  '1b_19': '',
#  '1b_20': '',
#  '1b_21': '',
#  '1b_22': '',
#  '1b_23': '',
#  '1b_24': '',
#  '1b_25': '',
#  '1b_26': '',
#  '1b_27': '',
#  '1b_28': ''}
