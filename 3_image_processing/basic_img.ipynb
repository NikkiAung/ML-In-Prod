# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/envs/dev_env/lib/python3.10/site-packages (from opencv-python) (2.2.1)
# Using cached opencv_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84

# %%
import cv2
import os, sys
import matplotlib.pyplot as plt

root_path = os.getcwd()
bgr_img = cv2.imread(root_path+r"/test_imgs/test_1.png") #Blue, green, red
print(root_path)
# print(input_img)
print(type(bgr_img))
print(bgr_img.shape)
plt.imshow(bgr_img)
# Out:
# /Users/aungnandaoo/Desktop/ML-in-Prod/3_image_processing
# <class 'numpy.ndarray'>
# (315, 600, 3)

# %%
rgb_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)

# %%
from PIL import Image
pil_img = Image.open(root_path+r"/test_imgs/test_1.png")
print(type(pil_img))
print(pil_img.size)
plt.imshow(pil_img)
# Out:
# <class 'PIL.WebPImagePlugin.WebPImageFile'>
# (600, 315)
